# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ID = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all.npy', allow_pickle=True)

# %%
ID_test2017 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_test2017.npy', allow_pickle=True)
ID_horizontal_shift = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_vertical_shift = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_vertical_shift.npy', allow_pickle=True)
ID_vertical_flip = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_vertical_flip.npy', allow_pickle=True)
ID_horizontal_flip = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_channel_shift = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_channel_shift.npy', allow_pickle=True)
ID_rotation = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_rotation.npy', allow_pickle=True)

# %%
ID_channel_shift_5000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_all_channel_shift_5000.npy', allow_pickle=True)

# %%
layers = ['input', 'pool1', 'pool2', 'pool3', 'pool4', 'pool5', 'rpn_c', 'rpn_b', 'roi', 'fc', 'cls_p', 'bbox_p']

# %%
fig = plt.figure()
fig.set_size_inches(4, 4)
plt.plot(layers, ID_test2017[:,0], label='unaugmented', marker = 'o')
plt.plot(layers, ID_horizontal_shift[:,0], label='horizontal_shift', marker='+')
plt.plot(layers, ID_vertical_shift[:,0], label='vertical_shift', marker='*')
plt.plot(layers, ID_vertical_flip[:,0], label='vertical_flip', marker='s')
plt.plot(layers, ID_horizontal_flip[:,0], label='horizontal_flip',marker='x')
plt.plot(layers, ID_channel_shift[:,0], label='channel_shift',marker='d')
plt.plot(layers, ID_rotation[:,0], label='rotation',marker='p')
plt.legend()
plt.xticks(rotation=90) 
plt.savefig('6.png')

# %%
import pandas as pd

# %%
ID_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_test2017.npy', allow_pickle=True)
ID_channel_shift_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_1000 = np.load('../trained_model/coco/faster_rcnn/vgg16/ID_1000/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
ID_rotation_1000
# Out:
# array([[22.55960489,  0.55871795],
#        [44.94049837,  1.34493715],
#        [53.48687036,  5.12067828],
#        [48.63941573,  1.91670212],
#        [65.17544998,  1.40646457],
#        [44.5107019 ,  0.85217498],
#        [24.69500229,  0.28504113],
#        [28.21687472,  0.6392993 ],
#        [22.42868584,  0.46825897],
#        [17.27185456,  0.33586362],
#        [13.64788813,  0.34646909],
#        [10.36138773,  0.19374738]])

# %%
plt.plot(layers, ID_1000[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_1000[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_1000[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_1000[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_1000[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_1000[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_1000[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_test2017.npy', allow_pickle=True)
ID_channel_shift_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_vgg19 = np.load('../trained_model/coco/faster_rcnn/vgg19/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_vgg19[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_vgg19[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_vgg19[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_vgg19[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_vgg19[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_vgg19[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_vgg19[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_test2017.npy', allow_pickle=True)
ID_channel_shift_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_vgg19_2000 = np.load('../trained_model/coco/faster_rcnn/vgg19/2000/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_vgg19_2000[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_vgg19_2000[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_vgg19_2000[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_vgg19_2000[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_vgg19_2000[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_vgg19_2000[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_vgg19_2000[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_test2017.npy', allow_pickle=True)
ID_channel_shift_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_res = np.load('../trained_model/coco/faster_rcnn/resnet_101/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_res[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_res[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_res[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_res[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_res[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_res[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_res[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_res
# Out:
# array([[2.77762049e+01, 8.02655179e-01],
#        [5.72750383e+01, 1.62523407e+00],
#        [6.74416456e+01, 3.71458092e+00],
#        [1.30539250e+02, 3.60675860e+01],
#        [1.10391398e+02, 6.25898025e+00],
#        [1.37969882e+01, 3.37268643e-01],
#        [3.32049103e+00, 6.39407386e-02],
#        [4.40354281e+00, 9.89096296e-02],
#        [1.35663232e+01, 2.67562043e-01],
#        [9.41673997e+00, 1.68200193e-01],
#        [7.81421490e+00, 1.55650705e-01],
#        [1.07436230e+01, 2.14665064e-01]])
