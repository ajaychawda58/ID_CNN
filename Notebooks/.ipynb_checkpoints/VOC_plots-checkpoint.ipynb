# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ID = np.load('../trained_model/pascal_voc/faster_rcnn/vgg16/ID_all.npy',allow_pickle=True)

# %%
ID_JPEGImages = np.load('ID_all_JPEGImages.npy', allow_pickle=True)
ID_channel_shift = np.load('ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip = np.load('ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift = np.load('ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation = np.load('ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip = np.load('ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift = np.load('ID_all_vertical_shift.npy', allow_pickle=True)

# %%
ID_channel_shift_5000 = np.load('ID_all_channel_shift_5000.npy', allow_pickle=True)
ID_horizontal_flip_5000 = np.load('ID_all_horizontal_flip_5000.npy', allow_pickle=True)

# %%
layers = ['input', 'pool1', 'pool2', 'pool3', 'pool4', 'pool5', 'rpn_c', 'rpn_b', 'roi', 'fc', 'cls_p', 'bbox_p']

# %%
ID_rotation
# Out:
# array([[26.66309133,  0.46786224],
#        [63.03247251,  2.32613701],
#        [61.13523536,  2.64473072],
#        [52.90211532,  4.99419859],
#        [56.08154564,  2.0953298 ],
#        [53.4704969 ,  0.92823078],
#        [24.80679481,  0.35548185],
#        [41.83703374,  0.37788388],
#        [34.0069424 ,  0.46587182],
#        [24.89381531,  0.30368181],
#        [11.67681179,  0.13617505],
#        [14.73782853,  0.21644028]])

# %%
fig = plt.figure()
fig.set_size_inches(4, 4)
plt.plot(layers, ID_JPEGImages[:,0], label='unaugmented', marker = 'o')
plt.plot(layers, ID_horizontal_shift[:,0], label='horizontal_shift', marker='+')
plt.plot(layers, ID_vertical_shift[:,0], label='vertical_shift', marker='*')
plt.plot(layers, ID_vertical_flip[:,0], label='vertical_flip', marker='s')
plt.plot(layers, ID_horizontal_flip[:,0], label='horizontal_flip',marker='x')
plt.plot(layers, ID_channel_shift[:,0], label='channel_shift',marker='d')
plt.plot(layers, ID_rotation[:,0], label='rotation',marker='p')
plt.legend()
plt.xticks(rotation=90) 
plt.savefig('5.png')

# %%
import pandas as pd

# %%
ID_1000 = np.load('ID_1000/ID_all_JPEGImages.npy', allow_pickle=True)
ID_channel_shift_1000 = np.load('ID_1000/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_1000 = np.load('ID_1000/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_1000 = np.load('ID_1000/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_1000 = np.load('ID_1000/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_1000 = np.load('ID_1000/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_1000 = np.load('ID_1000/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
ID_rotation_1000
# Out:
# array([[24.72898719,  0.5203053 ],
#        [81.06224665,  1.69652731],
#        [71.73506726,  3.1903412 ],
#        [66.01806311,  8.48418889],
#        [50.82151499,  2.58659944],
#        [48.1261835 ,  1.16195992],
#        [23.92906073,  0.38300176],
#        [38.41894   ,  0.84318934],
#        [31.08239378,  0.66228903],
#        [23.53696644,  0.35077243],
#        [11.21386041,  0.17469493],
#        [13.13154186,  0.22208705]])

# %%
plt.plot(layers, ID_1000[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_1000[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_1000[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_1000[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_1000[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_1000[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_1000[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_vgg19 = np.load('../vgg19/ID_all_JPEGImages.npy', allow_pickle=True)
ID_channel_shift_vgg19 = np.load('../vgg19/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_vgg19 = np.load('../vgg19/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_vgg19 = np.load('../vgg19/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_vgg19 = np.load('../vgg19/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_vgg19 = np.load('../vgg19/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_vgg19 = np.load('../vgg19/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_vgg19[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_vgg19[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_vgg19[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_vgg19[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_vgg19[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_vgg19[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_vgg19[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_vgg19_2000 = np.load('../vgg19/2000/ID_all_JPEGImages.npy', allow_pickle=True)
ID_channel_shift_vgg19_2000 = np.load('../vgg19/2000/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_vgg19_2000 = np.load('../vgg19/2000/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_vgg19_2000 = np.load('../vgg19/2000/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_vgg19_2000 = np.load('../vgg19/2000/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_vgg19_2000 = np.load('../vgg19/2000/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_vgg19_2000 = np.load('../vgg19/2000/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_vgg19_2000[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_vgg19_2000[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_vgg19_2000[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_vgg19_2000[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_vgg19_2000[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_vgg19_2000[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_vgg19_2000[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()

# %%
ID_res = np.load('../resnet_101/ID_all_JPEGImages.npy', allow_pickle=True)
ID_channel_shift_res = np.load('../resnet_101/ID_all_channel_shift.npy', allow_pickle=True)
ID_horizontal_flip_res = np.load('../resnet_101/ID_all_horizontal_flip.npy', allow_pickle=True)
ID_horizontal_shift_res = np.load('../resnet_101/ID_all_horizontal_shift.npy', allow_pickle=True)
ID_rotation_res = np.load('../resnet_101/ID_all_rotation.npy', allow_pickle=True)
ID_vertical_flip_res = np.load('../resnet_101/ID_all_vertical_flip.npy', allow_pickle=True)
ID_vertical_shift_res = np.load('../resnet_101/ID_all_vertical_shift.npy', allow_pickle=True)

# %%
plt.plot(layers, ID_res[:,0], label='unaugmented')
plt.plot(layers, ID_channel_shift_res[:,0], label='channel_shift')
plt.plot(layers, ID_horizontal_flip_res[:,0], label='horizontal_flip')
plt.plot(layers, ID_horizontal_shift_res[:,0], label='horizontal_shift')
plt.plot(layers, ID_rotation_res[:,0], label='rotation')
plt.plot(layers, ID_vertical_flip_res[:,0], label='vertical_flip')
plt.plot(layers, ID_vertical_shift_res[:,0], label='vertical_shift')
plt.legend()
plt.xticks(rotation=90) 
plt.show()
